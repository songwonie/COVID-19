# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import folium
import seaborn as sns
import missingno as msno

# %%
plt.rc("font", family="Malgun Gothic")
plt.style.use("ggplot")

# %%
time = pd.read_csv("Time.csv", encoding="utf-8")

# %%
time
# Out:
#            date  time    test  negative  confirmed  released  deceased
# 0    2020-01-20    16       1         0          1         0         0
# 1    2020-01-21    16       1         0          1         0         0
# 2    2020-01-22    16       4         3          1         0         0
# 3    2020-01-23    16      22        21          1         0         0
# 4    2020-01-24    16      27        25          2         0         0
# ..          ...   ...     ...       ...        ...       ...       ...
# 128  2020-05-27     0  852876    820550      11265     10295       269
# 129  2020-05-28     0  868666    834952      11344     10340       269
# 130  2020-05-29     0  885120    849161      11402     10363       269
# 131  2020-05-30     0  902901    865162      11441     10398       269
# 132  2020-05-31     0  910822    876060      11468     10405       270
#
# [133 rows x 7 columns]

# %%
msno.matrix(time)

# %%
plt.figure(figsize=(20,10))
plt.plot(time["date"], time["confirmed"], marker="o", markersize=5)
plt.title("대한민국 감염자수")
plt.xlabel("날짜")
plt.xticks(rotation="vertical")
plt.ylabel("감염자수")
plt.legend(labels=["감염자수"], loc="best", fontsize=10)
#대한민국 총 감염자수 나타내는 그래프
